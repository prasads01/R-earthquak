# %% [markdown]
# <a href="https://colab.research.google.com/github/prasads01/R-earthquak/blob/main/Notebook13_july.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/Salaries.csv')

# %%
df.head
# Out:
# <bound method NDFrame.head of          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]>

# %%
df[df['salary']>120000]
# Out:
#     rank discipline  phd  service     sex  salary
# 0   Prof          B   56       49    Male  186960
# 3   Prof          A   40       31    Male  131205
# 5   Prof          A   20       20    Male  122400
# 7   Prof          A   18       18    Male  126300
# 10  Prof          B   39       33    Male  128250
# 11  Prof          B   23       23    Male  134778
# 13  Prof          B   35       33    Male  162200
# 14  Prof          B   25       19    Male  153750
# 15  Prof          B   17        3    Male  150480
# 19  Prof          A   29       27    Male  150500
# 26  Prof          A   38       19    Male  148750
# 27  Prof          A   45       43    Male  155865
# 29  Prof          B   21       20    Male  123683
# 31  Prof          B   22       21    Male  155750
# 35  Prof          B   28       23    Male  126933
# 36  Prof          B   45       45    Male  146856
# 39  Prof          B   18       18  Female  129000
# 40  Prof          A   39       36  Female  137000
# ...

# %%
df[df['salary']<120000]
# Out:
#          rank discipline  phd  service     sex  salary
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 4        Prof          B   20       18    Male  104800
# 6   AssocProf          A   20       17    Male   81285
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 12   AsstProf          B    1        0    Male   88000
# 16   AsstProf          B    8        3    Male   75044
# 17   AsstProf          B    4        0    Male   92000
# 18       Prof          A   19        7    Male  107300
# 20   AsstProf          B    4        4    Male   92000
# 21       Prof          A   33       30    Male  103106
# 22   AsstProf          A    4        2    Male   73000
# 23   AsstProf          A    2        0    Male   85000
# 24       Prof          A   30       23    Male   91100
# 25       Prof          B   35       31    Male   99418
# ...

# %%
df[((df['salary']>120000)&(df['rank']=='Prof'))]
# Out:
#     rank discipline  phd  service     sex  salary
# 0   Prof          B   56       49    Male  186960
# 3   Prof          A   40       31    Male  131205
# 5   Prof          A   20       20    Male  122400
# 7   Prof          A   18       18    Male  126300
# 10  Prof          B   39       33    Male  128250
# 11  Prof          B   23       23    Male  134778
# 13  Prof          B   35       33    Male  162200
# 14  Prof          B   25       19    Male  153750
# 15  Prof          B   17        3    Male  150480
# 19  Prof          A   29       27    Male  150500
# 26  Prof          A   38       19    Male  148750
# 27  Prof          A   45       43    Male  155865
# 29  Prof          B   21       20    Male  123683
# 31  Prof          B   22       21    Male  155750
# 35  Prof          B   28       23    Male  126933
# 36  Prof          B   45       45    Male  146856
# 39  Prof          B   18       18  Female  129000
# 40  Prof          A   39       36  Female  137000
# ...

# %%
## create subset salary less than  100000 or also & operator rank ==assocprof.
df[df((['salary']<100000)|(df['rank']=='Assocprof'))]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-00258841ecb7> in <module>()
#       1 ## create subset salary less than  100000 or also & operator rank ==assocprof.
# ----> 2 df[df((['salary']<100000)|(df['rank']=='Assocprof'))]
#
# TypeError: '<' not supported between instances of 'list' and 'int'

# %%
df[((df['salary']>100000)|(df['rank']=='AssocProf'))]
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# 18       Prof          A   19        7    Male  107300
# 19       Prof          A   29       27    Male  150500
# 21       Prof          A   33       30    Male  103106
# 26       Prof          A   38       19    Male  148750
# ...

# %%
df[((df['salary']>100000)&(df['rank']=='AssocProf'))]
# Out:
#          rank discipline  phd  service     sex  salary
# 30  AssocProf          B    9        7    Male  107008
# 34  AssocProf          B   12        8    Male  119800
# 47  AssocProf          B   11       11  Female  103613
# 59  AssocProf          B   12       10  Female  103994
# 61  AssocProf          B   13       10  Female  103750
# 62  AssocProf          B   14        7  Female  109650
# 74  AssocProf          B   19        6  Female  104542

# %%
df[['salary','service']]
# Out:
#     salary  service
# 0   186960       49
# 1    93000        6
# 2   110515       20
# 3   131205       31
# 4   104800       18
# ..     ...      ...
# 73  105450       10
# 74  104542        6
# 75  124312       17
# 76  109954       14
# 77  109646       15
#
# [78 rows x 2 columns]

# %%
df.iloc[3]
# Out:
# rank            Prof
# discipline         A
# phd               40
# service           31
# sex             Male
# salary        131205
# Name: 3, dtype: object

# %%
df.head
# Out:
# <bound method NDFrame.head of          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]>

# %%
df.iloc[-1]
# Out:
# rank            Prof
# discipline         A
# phd               23
# service           15
# sex           Female
# salary        109646
# Name: 77, dtype: object

# %%
df.iloc[:,0]
# Out:
# 0          Prof
# 1          Prof
# 2          Prof
# 3          Prof
# 4          Prof
#         ...
# 73         Prof
# 74    AssocProf
# 75         Prof
# 76         Prof
# 77         Prof
# Name: rank, Length: 78, dtype: object

# %%
df.iloc[0:2,0:3]
# Out:
#    rank discipline  phd
# 0  Prof          B   56
# 1  Prof          A   12

# %%
df.iloc[[0,4],[2,5]]
# Out:
#    phd  salary
# 0   56  186960
# 4   20  104800

# %%
## last row 
df.iloc[-1]
# Out:
# rank            Prof
# discipline         A
# phd               23
# service           15
# sex           Female
# salary        109646
# Name: 77, dtype: object

# %%
## first column
df.iloc[:,0]
# Out:
# 0          Prof
# 1          Prof
# 2          Prof
# 3          Prof
# 4          Prof
#         ...
# 73         Prof
# 74    AssocProf
# 75         Prof
# 76         Prof
# 77         Prof
# Name: rank, Length: 78, dtype: object

# %%
## for last colum
df.iloc[:,-1]
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
#        ...
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %%
##for row index 0 to 4 (5-1)
df.iloc[0:5]
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
df.iloc[:,1:3]## all rows & 1 and second column
# Out:
#    discipline  phd
# 0           B   56
# 1           A   12
# 2           A   23
# 3           A   40
# 4           B   20
# ..        ...  ...
# 73          B   18
# 74          B   19
# 75          B   17
# 76          A   28
# 77          A   23
#
# [78 rows x 2 columns]

# %%
df.iloc[2:5,0:3]## row indexes 2,3,4 & column index 0,1,2
# Out:
#    rank discipline  phd
# 2  Prof          A   23
# 3  Prof          A   40
# 4  Prof          B   20

# %%
df.iloc[[0,3],[2,5]]## index row no. 0 & 3 and column no. 2 & 5
# Out:
#    phd  salary
# 0   56  186960
# 3   40  131205

# %%
#filter first 10 rows
df.iloc[0:9]
# Out:
#         rank discipline  phd  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 1       Prof          A   12        6  Male   93000
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285
# 7       Prof          A   18       18  Male  126300
# 8       Prof          A   29       19  Male   94350

# %%
#slicing row indexes 3,4,5,6,7 & column index 3,4
df.iloc[3:8,3:5]
# Out:
#    service   sex
# 3       31  Male
# 4       18  Male
# 5       20  Male
# 6       17  Male
# 7       18  Male

# %%
#slicing last 10 rows index and column indexes 1 and 2 
df.iloc[-10:,1:3]
# Out:
#    discipline  phd
# 68          A    4
# 69          A   28
# 70          A    8
# 71          B   12
# 72          B   24
# 73          B   18
# 74          B   19
# 75          B   17
# 76          A   28
# 77          A   23

# %%
df.tail()
# Out:
#          rank discipline  phd  service     sex  salary
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
## last 5 rows
df.iloc[-5:]
# Out:
#          rank discipline  phd  service     sex  salary
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
## last 15 rows & 2 & 5th column
df.iloc[-15:,[1,4]]
# Out:
#    discipline     sex
# 63          A  Female
# 64          A  Female
# 65          A  Female
# 66          A  Female
# 67          A  Female
# 68          A  Female
# 69          A  Female
# 70          A  Female
# 71          B  Female
# 72          B  Female
# 73          B  Female
# 74          B  Female
# 75          B  Female
# 76          A  Female
# 77          A  Female

# %%
#50 $ 67 row & rank & salary
df.iloc[[50,67],[0,5]]
# Out:
#         rank  salary
# 50  AsstProf   97032
# 67      Prof   90450

# %%
df['salary'].agg('mean')
# Out:
# 108023.78205128205

# %%
df[['phd','salary']].agg(['mean','max','min'])
# Out:
#             phd         salary
# mean  19.705128  108023.782051
# max   56.000000  186960.000000
# min    1.000000   57800.000000

# %%
df.var()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# phd        1.562106e+02
# service    1.473740e+02
# salary     8.005313e+08
# dtype: float64

# %%
df.kurt()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# phd        0.042504
# service    0.608981
# salary    -0.401713
# dtype: float64
